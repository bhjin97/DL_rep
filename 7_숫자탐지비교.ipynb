# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
data_path = "datasets_num/data.yaml"
model.train(data=data_path, epochs=20, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
data_path = "Numbers/data.yaml"
model.train(data=data_path, epochs=20, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
# 하이퍼파라미터 탐색 수행
model.tune(
data="./Numbers/data.yaml",
epochs=20,
imgsz=640,
iterations=20, 
val=True
)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs\detect\tune5'
# Tuner:  Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/20 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'cutmix': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune5\tune_scatter_plots.png
# Saved runs\detect\tune5\tune_fitness.png
#
# Tuner: 1/20 iterations complete  (79.64s)
# Tuner: Results saved to runs\detect\tune5
# Tuner: Best fitness=0.17197 observed at iteration 1
# ...

# %%
# best_parameters.yaml
from ultralytics import YOLO

# 기본 모델 로드
model = YOLO("yolov8n.pt")

# 최적 파라미터로 학습
model.train(
    data="Numbers/data.yaml",
    cfg="runs/detect/tune5/best_hyperparameters.yaml",
    epochs=100,
    imgsz=640
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...
