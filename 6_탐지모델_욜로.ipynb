# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")

# %%
data_path = "datasets/data.yaml"
model.train(data=data_path, epochs=4, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
result = model.predict('rsp.jpg')
result[0].show()
# Out:
# image 1/1 c:\githome\DL_rep\rsp.jpg: 448x640 1 Paper, 1 Rock, 17.9ms
# Speed: 4.0ms preprocess, 17.9ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
model = YOLO('runs/detect/train4/weights/best.pt')
data_path = "datasets/data.yaml"
metrics = model.val(data=data_path)
print(metrics.results_dict)
# Out:
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 431.4172.0 MB/s, size: 29.1 KB)
# val: Scanning C:\githome\DL_rep\datasets\valid\labels.cache... 576 images, 238 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 576/576  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 36/36 10.6it/s 3.4s0.1s
#                    all        576        400      0.835       0.82      0.874      0.628
#                  Paper        132        139      0.824      0.755       0.82      0.551
#                   Rock        121        141      0.836      0.887      0.911       0.67
#               Scissors        116        120      0.845      0.817      0.891      0.663
# Speed: 0.5ms preprocess, 2.8ms inference, 0.0ms loss, 0.8ms postprocess per image
# ...

# %% [markdown]
# result = model.predict('rsp.jpg')
# print(result[0].boxes)
#
# import cv2
# import torch
# filename = 'rsp.jpg'
# img = cv2.imread(filename)
# for box in result[0].boxes:
#     x1, y1, x2, y2 = box.xyxy[0].numpy().flatten().astype(int)
#     cv2.rectangle(img, (x1,y1), (x2,y2), (0, 0, 255), 2)
#     cv2.putText(img, f'{int(box.cls)} {float(box.conf):.4f}', (x1,y1), cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 255))
#
# cv2.imshow('image', img)
# cv2.waitKey()
# cv2.destroyAllWindows()

# %%
import time, cv2, numpy as np, pandas as pd 
from ultralytics import YOLO

# 환경 설정 및 공통 변수
IMG_PATH = "rsp.jpg"  # 분석 대상 이미지 파일 경로
MODELS = ["yolov8n.pt", "C:/githome/DL_rep/runs/detect/train4/weights/best.pt"]  # 비교할 YOLO 모델 파일들의 경로
CONF_THR = 0.25  # 모델 추론 시 탐지 결과를 확정하는 최소 신뢰도(Confidence) 임계값. 값이 낮을수록 더 많은 객체를 탐지할 수 있으나, 오탐지 확률 증가
IOU_THR = 0.70  # NMS(Non-Maximum Suppression) 시 사용되는 IOU(Intersection Over Union) 임계값. 겹치는 바운딩 박스를 제거하는 기준으로, 값이 낮을수록 겹치는 박스를 더 적극적으로 제거함
IMG_SIZE = 640  # 모델에 입력되는 이미지의 크기(가로, 세로). 모든 모델에 동일하게 적용하여 공정한 비교를 위함

def run_once(model_path, img_path):
    # YOLO 모델 로드. 모델 경로를 인자로 받아 모델 객체를 생성
    model = YOLO(model_path)

    # 추론 (모델 실행)
    t0 = time.perf_counter()  # 추론 시작 시간 기록
    # model() 함수로 추론 실행. verbose=False로 설정하여 추론 과정의 상세 출력은 생략
    res = model(img_path, imgsz=IMG_SIZE, conf=CONF_THR, iou=IOU_THR, verbose=False)[0]
    latency_ms = (time.perf_counter() - t0) * 1000  # 추론에 걸린 시간(밀리초) 계산

    # 결과 시각화 및 저장
    vis = res.plot()  # 추론 결과를 시각화(바운딩 박스, 라벨 등)하여 NumPy 배열(BGR 형식)로 반환
    out_name = model_path.replace(".pt", "_result.png")  # 결과 이미지 저장 파일명 생성
    cv2.imwrite(out_name, vis)  # 시각화된 이미지를 파일로 저장

    # 기본 통계 정보 추출
    num = int(len(res.boxes))  # 탐지된 객체(바운딩 박스)의 총 개수
    # 탐지된 객체들의 신뢰도 평균 계산. 객체가 없으면 0.0 반환
    mean_conf = float(res.boxes.conf.mean().item()) if num > 0 else 0.0
    # 탐지된 객체의 클래스 ID 목록 추출
    classes = [int(c) for c in res.boxes.cls.tolist()] if num > 0 else []
    # 클래스 ID를 사람이 읽을 수 있는 이름으로 변환
    class_names = [res.names[c] for c in classes]
    # 각 클래스별 탐지된 객체 수 계산
    uniq, counts = np.unique(class_names, return_counts=True)
    class_breakdown = dict(zip(uniq.tolist(), counts.tolist()))

    # 마스크(세그멘테이션) 면적 비율 계산 (모델이 세그멘테이션을 지원할 경우에만)
    mask_ratio = None
    if getattr(res, "masks", None) is not None and res.masks is not None:
        m = res.masks.data  # 세그멘테이션 마스크 데이터(Tensor)
        area = float(m.sum().item())  # 마스크 영역의 총 픽셀 수 계산
        H, W = m.shape[-2], m.shape[-1]  # 마스크의 높이와 너비
        mask_ratio = area / (H * W)  # 마스크 영역이 전체 이미지에서 차지하는 비율 계산

    # 결과를 딕셔너리 형태로 반환
    return {
        "model": model_path,
        "latency_ms": round(latency_ms, 2),  # 추론 시간
        "detections": num,  # 탐지된 객체 수
        "mean_conf": round(mean_conf, 4),  # 평균 신뢰도
        "classes": class_breakdown,  # 클래스별 탐지 객체 수
        "mask_ratio": round(mask_ratio, 6) if mask_ratio is not None else None,  # 마스크 비율
        "out_image": out_name
    }

# 메인 실행부
rows = [run_once(m, IMG_PATH) for m in MODELS]  # MODELS 리스트의 각 모델에 대해 run_once 함수를 실행
df = pd.DataFrame(rows, columns=[
    "model", "latency_ms", "detections", "mean_conf", "classes", "mask_ratio", "out_image"
])  # 반환된 딕셔너리 리스트를 Pandas DataFrame으로 변환

print(df.to_string(index=False))  # 데이터프레임을 인덱스 없이 깔끔한 문자열 표 형태로 출력
# Out:
#                                                model  latency_ms  detections  mean_conf                 classes mask_ratio                                                    out_image
#                                           yolov8n.pt       88.90           3     0.6769           {'person': 3}       None                                           yolov8n_result.png
# C:/githome/DL_rep/runs/detect/train4/weights/best.pt       78.51           2     0.8275 {'Paper': 1, 'Rock': 1}       None C:/githome/DL_rep/runs/detect/train4/weights/best_result.png

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
# 하이퍼파라미터 탐색 수행
model.tune(
data="./datasets/data.yaml",
epochs=5,
imgsz=640,
iterations=5, 
val=True
)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs\detect\tune'
# Tuner:  Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/5 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'cutmix': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune\tune_scatter_plots.png
# Saved runs\detect\tune\tune_fitness.png
#
# Tuner: 1/5 iterations complete  (269.76s)
# Tuner: Results saved to runs\detect\tune
# Tuner: Best fitness=0.71376 observed at iteration 1
# ...

# %%
# best_parameters.yaml
from ultralytics import YOLO

# 기본 모델 로드
model = YOLO("yolov8n.pt")

# 최적 파라미터로 학습
model.train(
    data="datasets/data.yaml",
    cfg="runs/detect/tune/best_hyperparameters.yaml",
    epochs=4,
    imgsz=640
)
# Out:
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
result = model.predict('rsp.jpg')
result[0].show()
# Out:
# image 1/1 c:\githome\DL_rep\rsp.jpg: 448x640 1 Paper, 1 Rock, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)

# %%
학습전: {'metrics/precision(B)': 0.835295233707539, 'metrics/recall(B)': 0.81952905760498, 'metrics/mAP50(B)': 0.8739036304538715, 'metrics/mAP50-95(B)': 0.6279757222315253, 'fitness': 0.65256851305376}

학습후: {'metrics/precision(B)': 0.8668720878169998, 'metrics/recall(B)': 0.8343346905760805, 'metrics/mAP50(B)': 0.8767224812267003, 'metrics/mAP50-95(B)': 0.6388264097321432, 'fitness': 0.662616016881599}

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
# 하이퍼파라미터 탐색 수행
model.tune(
data="./Numbers/data.yaml",
epochs=5,
imgsz=640,
iterations=5, 
val=True
)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs\detect\tune2'
# Tuner:  Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/5 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'cutmix': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune2\tune_scatter_plots.png
# Saved runs\detect\tune2\tune_fitness.png
#
# Tuner: 1/5 iterations complete  (52.29s)
# Tuner: Results saved to runs\detect\tune2
# Tuner: Best fitness=0.02184 observed at iteration 1
# ...

# %%
# best_parameters.yaml
from ultralytics import YOLO

# 기본 모델 로드
model = YOLO("yolov8n.pt")

# 최적 파라미터로 학습
model.train(
    data="Numbers/data.yaml",
    cfg="runs/detect/tune2/best_hyperparameters.yaml",
    epochs=20,
    imgsz=640
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
data_path = "datasets_num/data.yaml"
model.train(data=data_path, epochs=20, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
data_path = "Numbers/data.yaml"
model.train(data=data_path, epochs=20, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...
